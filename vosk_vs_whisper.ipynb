# %%
#Short Vosk vs Whisper Script

# !pip install -q vosk gTTS faster-whisper pydub soundfile sentencepiece 
# !apt-qq install -y ffmpeg
# Out:
# 'apt-qq' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install gTTS
# Out:
# Requirement already satisfied: gTTS in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from gTTS) (2.32.5)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from gTTS) (8.1.8)
# Requirement already satisfied: colorama in c:\users\mahes\appdata\roaming\python\python313\site-packages (from click<8.2,>=7.1->gTTS) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->gTTS) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->gTTS) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->gTTS) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->gTTS) (2025.11.12)

# %%
from google.colab import files 
from gtts import gTTS
from IPython.display import Audio
import os, wave, json, subprocess

#AUDIO PREP
print("Upload audio (optional). Skip to auto-create TTS sample.")
up=files.upload()

if up:
    audio =list(up.keys())[0]
else:
    tts=gTTS("Hello! This is a test audio for comparing Vosk and Whisper.", lang="en")
    audio ="sample.mp3"
    tts.save(audio)

#Convert WAV to 16khz mono

wav= "audio.wav"
subprocess.run(["ffmpeg","-y","-i", audio, "-ar", "16000","-ac", "1", wav], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

Audio(wav)


#---vosk---

if not os.path.exists("vosk-model"):

    # !wget -q https://alphacephes.com/vosk/models/vosk-model-small-en-us-0.15.zip -O model.zip
    # !unzip -q model.zip
    # !mv vosk-model-small-en-us-0.15 vosk-model
    # !rm model.zip

from vosk import Model, KaldiRecognizer
wf = wave.open(wav, "rb")
rec = KaldiRecognizer(Model("vosk-model"), wf.getframerate())
vosk_text = ""

while True:

    data = wf.readframes(4000)
    if not data: break
    if rec. AcceptWaveform(data):
        vosk_test += json.loads(rec.Result()).get("text","")+ " "
vosk_test += json.loads(Pec.FinalResult()).get("text","") 

#=== Whisper ===
import torch
from faster_whisper import WhisperModel

device= "cuda" if torch.cuda.is_available() else "cpu"
wmodel= WhisperModel("small", device=device)

segments, _= wmodel.transcribe(wav)
whisper_text=" ".join([s.text for s in segments]).strip()

print("\n>>> WHISPER:\n", whisper_text)

#this program works in collab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from google.colab import files
#       2 from gtts import gTTS
#       3 from IPython.display import Audio
#
# ModuleNotFoundError: No module named 'google.colab'
