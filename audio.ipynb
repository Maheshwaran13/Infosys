# %%
# !pip install sounddevice vosk faster-whisper soundfile
# !apt-get install -y portaudio19-dev
# Out:
# Collecting sounddevice
#   Downloading sounddevice-0.5.3-py3-none-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: vosk in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (0.3.45)
# Requirement already satisfied: faster-whisper in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (1.2.1)
# Requirement already satisfied: soundfile in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (0.13.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: requests in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from vosk) (2.32.5)
# Requirement already satisfied: srt in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from vosk) (3.5.3)
# Requirement already satisfied: tqdm in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from vosk) (4.67.1)
# Requirement already satisfied: websockets in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from vosk) (15.0.1)
# Requirement already satisfied: ctranslate2<5,>=4.0 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from faster-whisper) (4.6.1)
# Requirement already satisfied: huggingface-hub>=0.21 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from faster-whisper) (1.1.4)
# Requirement already satisfied: tokenizers<1,>=0.13 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from faster-whisper) (0.22.1)
# Requirement already satisfied: onnxruntime<2,>=1.14 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from faster-whisper) (1.23.2)
# Requirement already satisfied: av>=11 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from faster-whisper) (16.0.1)
# Requirement already satisfied: setuptools in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from ctranslate2<5,>=4.0->faster-whisper) (80.9.0)
# Requirement already satisfied: numpy in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.3.3)
# Requirement already satisfied: pyyaml<7,>=5.3 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.3)
# Requirement already satisfied: coloredlogs in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime<2,>=1.14->faster-whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.9.23)
# Requirement already satisfied: packaging in c:\users\mahes\appdata\roaming\python\python313\site-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.0)
# Requirement already satisfied: protobuf in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime<2,>=1.14->faster-whisper) (6.33.1)
# Requirement already satisfied: sympy in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.14.0)
# Requirement already satisfied: filelock in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.21->faster-whisper) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.21->faster-whisper) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.21->faster-whisper) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.21->faster-whisper) (0.28.1)
# Requirement already satisfied: shellingham in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.21->faster-whisper) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.21->faster-whisper) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.21->faster-whisper) (4.15.0)
# Requirement already satisfied: anyio in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (4.11.0)
# Requirement already satisfied: certifi in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (1.0.9)
# Requirement already satisfied: idna in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from CFFI>=1.0->sounddevice) (2.23)
# Requirement already satisfied: colorama in c:\users\mahes\appdata\roaming\python\python313\site-packages (from tqdm->vosk) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.21->faster-whisper) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime<2,>=1.14->faster-whisper) (3.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from requests->vosk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from requests->vosk) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\mahes\appdata\local\programs\python\python313\lib\site-packages (from typer-slim->huggingface-hub>=0.21->faster-whisper) (8.1.8)
# Downloading sounddevice-0.5.3-py3-none-win_amd64.whl (364 kB)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.5.3
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from gtts import gTTS
from IPython.display import Audio

tts = gTTS("Hello, this is a test audio for speech to text models.", lang="en")
tts.save("test_audio.mp3")

Audio("test_audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !ffmpeg -i test_audio.mp3 -ar 16000 -ac 1 test.wav -y
# Out:
# 'ffmpeg' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !wget -q https://alphacephei.com/vosk/models/vosk-model-small-en-us-0.15.zip
# !unzip -q vosk-model-small-en-us-0.15.zip

from vosk import Model, KaldiRecognizer
import wave, json

wf = wave.open("test.wav", "rb")
rec = KaldiRecognizer(Model("vosk-model-small-en-us-0.15"), 16000)
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 from vosk import Model, KaldiRecognizer
#       5 import wave, json
# ----> 7 wf = wave.open("test.wav", "rb")
#       8 rec = KaldiRecognizer(Model("vosk-model-small-en-us-0.15"), 16000)
#
# File c:\Users\mahes\AppData\Local\Programs\Python\Python313\Lib\wave.py:659, in open(f, mode)
#     657         mode = 'rb'
#     658 if mode in ('r', 'rb'):
# --> 659     return Wave_read(f)
#     660 elif mode in ('w', 'wb'):
#     661     return Wave_write(f)
#
# File c:\Users\mahes\AppData\Local\Programs\Python\Python313\Lib\wave.py:282, in Wave_read.__init__(self, f)
#     280 self._i_opened_the_file = None
#     281 if isinstance(f, str):
# --> 282     f = builtins.open(f, 'rb')
#     283     self._i_opened_the_file = f
#     284 # else, assume it is an open file object already
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.wav'
